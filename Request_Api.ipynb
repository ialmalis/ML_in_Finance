# %%
import requests
import pandas as pd
import datetime
import json

# %% [markdown]
# ## Technology

# %%
for i in range(8,0,-1):
   
    s="https://stocknewsapi.com/api/v1/category?section=alltickers&sector=technology&page="+str(i)+"&items=50&token=qhs7voph5mdtwumyt8lgh8aqzmqglgziwmm3g58q"
    response = requests.request("GET",s)
    json_d = response.json()
    with open("Tech_news.json","a") as fp:    
        json.dump(json_d,fp)

# %%
response = requests.request("GET","https://stocknewsapi.com/api/v1/category?section=alltickers&sector=technology&page=8&items=50&token=qhs7voph5mdtwumyt8lgh8aqzmqglgziwmm3g58q")
json_d = response.json()
print(json_d)
# Out:
# {'data': [{'news_url': 'https://www.businesswire.com/news/home/20200831005009/en/FP-Corporation-Switches-Rimini-Street-Support-SAP/', 'image_url': 'https://cdn.snapi.dev/images/v1/z/m/press11-3.jpg', 'title': 'FP Corporation Switches to Rimini Street Support for Its SAP Applications', 'text': 'LAS VEGAS--(BUSINESS WIRE)---- $RMNI #RMNI--Japan’s largest manufacturer of disposable food containers defers costly move to S/4HANA and maximizes ROI from existing SAP releases', 'source_name': 'Business Wire', 'date': 'Mon, 31 Aug 2020 16:00:00 -0400', 'topics': ['PressRelease'], 'sentiment': 'Neutral', 'type': 'Article', 'tickers': ['RMNI']}, {'news_url': 'https://www.cnbc.com/2020/08/31/zoom-earnings-trader-shares-what-level-would-be-a-buy-in-the-stock.html', 'image_url': 'https://cdn.snapi.dev/images/v1/v/e/3500jpgwidth460quality85autoformatfitmaxsd2397ff2b89ccf1fc05ae5b759276821.jpg', 'title': 'Zoom hits record high ahead of earnings. Trader shares what level would be a buy', 'text': 'Zoo
# ...

# %% [markdown]
# ## All_Tickers

# %%
for i in range(31,0,-1):
    s="https://stocknewsapi.com/api/v1/category?section=alltickers&page="+str(i)+"&items=50&token=qhs7voph5mdtwumyt8lgh8aqzmqglgziwmm3g58q"
    response = requests.request("GET",s)
    json_d = response.json()
    #print(json_d)
    with open("All_Tickers.json","a") as fp:
        json.dump(json_d,fp)

# %%
response = requests.request("GET","https://stocknewsapi.com/api/v1/category?section=alltickers&page=31&items=50&token=qhs7voph5mdtwumyt8lgh8aqzmqglgziwmm3g58q")
json_d = response.json()
print(json_d)
# Out:
# {'data': [{'news_url': 'https://www.prnewswire.com/news-releases/origin-agritech-to-present-at-the-ld-500-virtual-conference-301121159.html', 'image_url': 'https://cdn.snapi.dev/images/v1/y/j/press16.jpg', 'title': 'Origin Agritech to Present at The LD 500 Virtual Conference', 'text': 'BEIJING,, Aug. 31, 2020 /PRNewswire/ -- Origin Agritech Ltd.', 'source_name': 'PRNewsWire', 'date': 'Mon, 31 Aug 2020 13:41:00 -0400', 'topics': ['PressRelease'], 'sentiment': 'Neutral', 'type': 'Article', 'tickers': ['SEED']}, {'news_url': 'https://seekingalpha.com/article/4371738-pfm-possible-option-while-wait-for-economic-clarity?utm_source=feed_articles_etfs_and_funds_etf_analysis&utm_medium=referral', 'image_url': 'https://cdn.snapi.dev/images/v1/s/v/etf27.jpg', 'title': 'PFM: A Possible Option While We Wait For Economic Clarity', 'text': 'PFM: A Possible Option While We Wait For Economic Clarity', 'source_name': 'Seeking Alpha', 'date': 'Mon, 31 Aug 2020 13:40:31 -0400', 'topics': [], 'sentiment'
# ...
